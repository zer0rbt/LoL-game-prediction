# %% [markdown]
# # League of Legends data collection method

# %%
import requests
import time
import numpy
import csv
import config1

#Note: in file config1 should be list "API_KEYS" with api keys. (RiotAPI is kinda slow, so you should have more than 1 key)
api_key = config1.API_KEY # "INSERT YOUR RIOT DEVELOPMENT API KEY" 
region = 'europe'

# %% [markdown]
# ## Getting match data
# The following function is responsible for getting match data and checking if the match was a solo queue ranked game. If you want to try out different queues, change the queueId from 420 to a different one. If the match is ranked the function makes an api request to get the timeline data. Timeline data contains match states for each minute of the match.

# %%
k = 0
def get_match_data(region, match_id, api_key):
  global k
  while True:
    resp = requests.get("https://" + region + ".api.riotgames.com/lol/match/v5/matches/"+ match_id +"?api_key="+api_key)
    if resp.status_code == 429:
      time.sleep(10)
      k += 1
      k =k % len(config1.API_KEYS)
      time.sleep(10)
      api_key = config1.API_KEYS[k]
      print(f'sleeping w/ {api_key[-4:]}')
      continue
    elif resp.status_code == 200:
      break
    elif resp.status_code == 404:
      return 0
    else:
      print('response is bad: ' + str(resp.status_code))

  match_data = resp.json()
  if match_data['info']['queueId'] == 420:
    while True:
      resp_timeline = requests.get("https://" + region + ".api.riotgames.com/lol/match/v5/matches/" + match_id + "/timeline?api_key=" + api_key)
      if resp_timeline.status_code == 429:
        k += 1
        k =k % len(config1.API_KEYS)
        time.sleep(10)
        api_key = config1.API_KEYS[k]
        print(f'sleeping w/ {api_key[-4:]}')
        continue
      elif resp_timeline.status_code == 200:
        break
      elif resp.status_code == 404:
        return 0
      else:
        print('response is bad: ' + str(resp.status_code))

    timeline_data = resp_timeline.json()
    return timeline_data
    print('timeline data returned')

  else:
    print ('Match wasnt ranked')
    return 0

# %% [markdown]
# ## Getting the match state at 15 minutes
# The function first checks if the match was shorter than 15 minutes. If it was shorter than 15 minutes then it makes no sense to get the match data. If the game was longer than 15 minutes then it returns an array containing all the chosen relevant features.

# %%
def get_match_state(data):

  blue_team = data['info']['participants'][:5]
  red_team = data['info']['participants'][5:]

  blueTeamMinionsKilled = 0
  redTeamMinionsKilled = 0
  blueTeamJungleMinions = 0
  redTeamJungleMinions = 0
  blueTeamTotalGold = 0
  redTeamTotalGold = 0
  blueTeamXp = 0
  redTeamXp = 0
  blueTeamTotalDamageToChamps = 0
  redTeamTotalDamageToChamps = 0
  blueTeamWardsPlaced = 0
  redTeamWardsPlaced = 0
  blueTeamTotalKills = 0
  redTeamTotalKills = 0
  blueTeamControlWardsPlaced = 0
  redTeamControlWardsPlaced = 0
  blueTeamDragonKills = 0
  redTeamDragonKills = 0
  blueTeamHeraldKills = 0
  redTeamHeraldKills = 0
  blueTeamTowersDestroyed = 0
  redTeamTowersDestroyed = 0
  blueTeamInhibitorsDestroyed = 0
  redTeamInhibitorsDestroyed = 0
  blueTeamTurretPlatesDestroyed = 0
  redTeamTurretPlatesDestroyed = 0
  blueTeamFirstBlood = 0
  blueWin = 0

  if len(data['info']['frames']) < 16:
    return 0

  for player in blue_team:
    blueTeamMinionsKilled += data['info']['frames'][15]['participantFrames'][str(player['participantId'])]['minionsKilled']
    blueTeamTotalGold += data['info']['frames'][15]['participantFrames'][str(player['participantId'])]['totalGold']
    blueTeamXp += data['info']['frames'][15]['participantFrames'][str(player['participantId'])]['xp']
    blueTeamJungleMinions += data['info']['frames'][15]['participantFrames'][str(player['participantId'])]['jungleMinionsKilled']
    blueTeamTotalDamageToChamps += data['info']['frames'][15]['participantFrames'][str(player['participantId'])]['damageStats']['totalDamageDoneToChampions']

  for player in red_team:
    redTeamMinionsKilled += data['info']['frames'][15]['participantFrames'][str(player['participantId'])]['minionsKilled']
    redTeamTotalGold += data['info']['frames'][15]['participantFrames'][str(player['participantId'])]['totalGold']
    redTeamXp += data['info']['frames'][15]['participantFrames'][str(player['participantId'])]['xp']
    redTeamJungleMinions += data['info']['frames'][15]['participantFrames'][str(player['participantId'])]['jungleMinionsKilled']
    redTeamTotalDamageToChamps += data['info']['frames'][15]['participantFrames'][str(player['participantId'])]['damageStats']['totalDamageDoneToChampions']

  for event in data['info']['frames'][-1]['events']:
    if event['type'] == 'GAME_END':
      if event['winningTeam'] == 100:
        blueWin = 1

  for i in range(16):
    for event in data['info']['frames'][i]['events']:
      if event['type'] == 'WARD_PLACED':
        if event['creatorId'] in range(1,6):
          if event['wardType'] == 'CONTROL_WARD':
              blueTeamControlWardsPlaced += 1
          blueTeamWardsPlaced += 1
        else:
          if event['wardType'] == 'CONTROL_WARD':
            redTeamControlWardsPlaced += 1
          redTeamWardsPlaced += 1

      if event['type'] == 'CHAMPION_KILL':
        if event['killerId'] in range(1,6):
          blueTeamTotalKills += 1
        else:
          redTeamTotalKills += 1

      if event['type'] == 'ELITE_MONSTER_KILL':
        if event['monsterType'] == 'DRAGON':
          if event['killerId'] in range(1,6):
            blueTeamDragonKills += 1
          else:
            redTeamDragonKills += 1
        if event['monsterType'] == 'RIFTHERALD':
          if event['killerId'] in range(1,6):
            blueTeamHeraldKills += 1
          else:
            redTeamHeraldKills += 1

      if event['type'] == 'BUILDING_KILL' and event['buildingType'] == 'TOWER_BUILDING':
        if event['killerId'] in range(1,6):
          blueTeamTowersDestroyed += 1
        else:
          redTeamTowersDestroyed  += 1

      if event['type'] == 'BUILDING_KILL' and event['buildingType'] == 'INHIBITOR_BUILDING':
        if event['killerId'] in range(1,6):
          blueTeamInhibitorsDestroyed += 1
        else:
          redTeamInhibitorsDestroyed  += 1

      if event['type'] == 'TURRET_PLATE_DESTROYED':
        if event['killerId'] in range(1,6):
          redTeamTurretPlatesDestroyed += 1
        else:
          blueTeamTurretPlatesDestroyed  += 1

      if event['type'] == 'CHAMPION_SPECIAL_KILL' and event['killType'] == 'KILL_FIRST_BLOOD':
        if event['killerId'] in range(1,6):
          blueTeamFirstBlood = 1

  row = [[data['metadata']['matchId'], blueTeamControlWardsPlaced, blueTeamWardsPlaced, blueTeamTotalKills,blueTeamDragonKills,blueTeamHeraldKills,blueTeamTowersDestroyed,blueTeamInhibitorsDestroyed,
                       blueTeamTurretPlatesDestroyed,blueTeamFirstBlood,blueTeamMinionsKilled,blueTeamJungleMinions,blueTeamTotalGold,blueTeamXp,blueTeamTotalDamageToChamps, redTeamControlWardsPlaced,
                       redTeamWardsPlaced,redTeamTotalKills,redTeamDragonKills,redTeamHeraldKills,redTeamTowersDestroyed,redTeamInhibitorsDestroyed,redTeamTurretPlatesDestroyed,redTeamMinionsKilled,
                       redTeamJungleMinions,redTeamTotalGold,redTeamXp,redTeamTotalDamageToChamps,blueWin]]

  return row

  '''
  print("Control Wards: " + str(blueTeamControlWardsPlaced) + " : " + str(redTeamControlWardsPlaced))
  print("Wards: " + str(blueTeamWardsPlaced) + " : " + str(redTeamWardsPlaced))
  print("Total Kills: " + str(blueTeamTotalKills) + " : " + str(redTeamTotalKills))
  print("Dragons: " + str(blueTeamDragonKills) + " : " + str(redTeamDragonKills))
  print("Heralds: " + str(blueTeamHeraldKills) + " : " + str(redTeamHeraldKills))
  print("Towers: " + str(blueTeamTowersDestroyed) + " : " + str(redTeamTowersDestroyed))
  print("Inhibitors: " + str(blueTeamInhibitorsDestroyed) + " : " + str(redTeamInhibitorsDestroyed))
  print("Blue win: " + str(blueWin))
  print("Turret Plates: " + str(blueTeamTurretPlatesDestroyed) + " : " + str(redTeamTurretPlatesDestroyed))
  print("Blue first blood: " + str(blueTeamFirstBlood))
  print("Minions killed: " + str(blueTeamMinionsKilled) + " : " + str(redTeamMinionsKilled))
  print("Jungle minions killed: " + str(blueTeamJungleMinions) + " : " + str(redTeamJungleMinions))
  print("Total gold: " + str(blueTeamTotalGold) + " : " + str(redTeamTotalGold))
  print("Total Xp: " + str(blueTeamXp) + " : " + str(redTeamXp))
  print("Total damage: " + str(blueTeamTotalDamageToChamps) + " : " + str(redTeamTotalDamageToChamps))
  '''

# %% [markdown]
# ## Getting the seed players
# The process I used was to find a couple of players who spam a lot of ranked games recently in a desired rank. The loop then takes all of the players that participated in provided matches and puts them into a player_ids array. Around 300 seed matches is enough to yield 30 000 unique solo queue games in a desired rank. The result of this cell is a field containing all the players who participated in seed matches.

# %%
# player_ids = []
seed_match_ids = [6958778302, 6958623155, 6958344063, 6958379039, 6958447223, 6958507005, 6958815579, 6958794602, 6958744594, 6958665012, 6958262540, 6956731196, 6958829776, 6958421900, 6958734032, 6958507005, 6957546820
   # Populate this field with recent match ids from a desired rank
   # Rule of thumb: 100 seed matches will yield around 10 000 soloqueue games
  , 6958832944, 6958670455, 6957100312, 6958755009, 6958364051, 6958542269, 6958598414, 6958617736, 6958647754, 6958587185, 6958587185, 6958619610, 6958426836, 6958299521, 6958127241, 6958605571, 6958659823, 6958100884, 6958009709, 6958833836, 6958816933, 6958665012, 6958486644, 6958206832, 6958438964, 6958832865, 6958211129, 6956547501, 6958263339, 6958632091, 6958207021, 6952285263, 6958671632, 6958784898, 6958834571, 6957523075, 6958735730, 6958727694, 6958641864, 6958759279, 6958652351, 6958088093, 6957875530, 6958823762, 6956266617, 6958825107, 6958773627, 6958778302, 6958640796, 6957827847, 6958091869, 6958511452, 6958804394, 6958218138, 6958025176,
                  6958444650, 6958117067, 6958454952, 6958454952, 6958668546
]

i = 0

for seed_match_id in seed_match_ids:
  api_url = "https://" + region + ".api.riotgames.com/lol/match/v5/matches/EUW1_" + str(seed_match_id) + "?api_key="+ api_key

  while True:
    resp = requests.get(api_url)
    if resp.status_code == 429:
      time.sleep(10)
      print('sleeping')
      continue
    elif resp.status_code == 200:
      
      break
          
  match_data = resp.json()

  for participant in match_data['metadata']['participants']:
     if participant not in player_ids:
      player_ids = player_ids + [participant]
  print(len(player_ids))
  if len(player_ids) % 100 == 0:
    print(str(len(player_ids)))
    print(player_ids[-1])
# Out:
# sleeping
# 130
# 130
# 130
# 130
# 130
# 130
# 130
# 130
# 130
# 130
# 130
# 130
# 130
# 130
# 130
# 130
# 130
# 140
# 145
# 154
# 162
# 169
# 177
# 186
# 195
# 200
# 200
# DzVc7gWSIFSfBWCxiSm_qFDl95IDBzuZt-5ciNiVyta7ejCH0P3NSFbD3lzLz_ojukPo1HY6SxeuJQ
# 205
# 205
# 214
# 221
# 229
# 236
# 239
# 248
# 258
# 266
# 275
# 283
# 283
# 292
# 302
# 310
# 320
# 325
# 329
# 335
# 340
# 348
# 354
# 360
# 367
# 369
# 375
# 379
# 387
# 396
# 403
# 413
# 418
# 427
# 436
# 446
# 454
# 460
# 460
# 467
# 473
# 481
# 485
# 490
# 497
# 503
# 505
# 512
# 517
# 517
# 521

# %% [markdown]
# ## Getting the matches
# for each player enumerated from the above cell, the following cell takes 100 most recent matches. You can play around with that number but since some players only play occassionaly taking more than 20 matches might give us some matches from a previous season or from a lower / higher than desired rank. But since i was looking for challenger games, i've put that number on 100.

# %%
# match_ids = []
for player in player_ids[1:]:
  api_url = "https://" + region + ".api.riotgames.com/lol/match/v5/matches/by-puuid/" + player + "/ids?start=0&count=100&api_key="+ api_key

  while True:
    resp = requests.get(api_url)
    if resp.status_code == 429:
      time.sleep(10)
      print('sleeping')
      continue
    elif resp.status_code == 200:
      break
    else:
      print(str(resp.status_code))

  player_matches = resp.json()
  for match_id in player_matches:
    if match_id not in match_ids:
      match_ids = match_ids + [match_id]

  if len(match_ids) % 100 == 0:
    print(str(len(match_ids)))
# Out:
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# 17900
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# 24400
# 28700
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# sleeping
# 34400

# %%
pi = 0
processed_matches = []
data = ["heading_row"]
for match_id in match_ids:
  if match_id in processed_matches:
    print('match_already_processed')
  else:
    processed_matches = processed_matches + [match_id]
    timeline_data = get_match_data(region,match_id,config1.API_KEYS[k])
    if timeline_data != 0:
      row = get_match_state(timeline_data)
      if row != 0:
        data = data + [row]
    if i % 100 == 0:
      print(str(i) + " : "  + str(match_id))
    if len(data) % 500 == 0:
      with open('match_data.csv', 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerows(data)
      print("match data written at checkpoint: " + str(len(data)))
    i += 1
# Out:
# 0 : EUW1_6958829776
# sleeping w/ cb4d
# sleeping w/ e926
# 100 : EUW1_6954777188
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 200 : EUW1_6955867362
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 300 : EUW1_6955496980
# sleeping w/ cb4d
# sleeping w/ e926
# 400 : EUW1_6956507712
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 500 : EUW1_6956221756
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# match data written at checkpoint: 500
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 600 : EUW1_6954415815
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 700 : EUW1_6948875819
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# 800 : EUW1_6954520152
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 900 : EUW1_6947523803
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 1000 : EUW1_6944310356
# Match wasnt ranked
# sleeping w/ 8807
# Match wasnt ranked
# sleeping w/ fc41
# 1100 : EUW1_6950049265
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# Match wasnt ranked
# match data written at checkpoint: 1000
# sleeping w/ e926
# 1200 : EUW1_6918077959
# sleeping w/ 228d
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 1300 : EUW1_6958574437
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# 1400 : EUW1_6955329389
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# 1500 : EUW1_6940223990
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 1600 : EUW1_6941423020
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 1700 : EUW1_6944810627
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# match data written at checkpoint: 1500
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# 1800 : EUW1_6942706954
# sleeping w/ 8807
# Match wasnt ranked
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 1900 : EUW1_6943526313
# Match wasnt ranked
# sleeping w/ cb4d
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 2000 : EUW1_6957460289
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 2100 : EUW1_6955784976
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# 2200 : EUW1_6953548694
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# sleeping w/ 228d
# 2300 : EUW1_6944787217
# match data written at checkpoint: 2000
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# 2400 : EUW1_6956832640
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# 2500 : EUW1_6954294625
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 2600 : EUW1_6956325099
# sleeping w/ 8807
# sleeping w/ fc41
# Match wasnt ranked
# 2700 : EUW1_6943048422
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 2800 : EUW1_6947780153
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# sleeping w/ 8807
# match data written at checkpoint: 2500
# 2900 : EUW1_6949441186
# Match wasnt ranked
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 3000 : EUW1_6955824561
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# 3100 : EUW1_6954953675
# sleeping w/ 8807
# sleeping w/ fc41
# 3200 : EUW1_6954991514
# sleeping w/ cb4d
# sleeping w/ e926
# 3300 : EUW1_6953078229
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# 3400 : EUW1_6944571077
# Match wasnt ranked
# match data written at checkpoint: 3000
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 3500 : EUW1_6950054591
# Match wasnt ranked
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# Match wasnt ranked
# 3600 : EUW1_6949659278
# Match wasnt ranked
# sleeping w/ 228d
# sleeping w/ 8807
# Match wasnt ranked
# 3700 : EUW1_6952168606
# Match wasnt ranked
# sleeping w/ fc41
# Match wasnt ranked
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 3800 : EUW1_6957206290
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# 3900 : EUW1_6946943626
# sleeping w/ 8807
# sleeping w/ fc41
# 4000 : EUW1_6957846409
# match data written at checkpoint: 3500
# sleeping w/ cb4d
# Match wasnt ranked
# sleeping w/ e926
# 4100 : EUW1_6954385113
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# 4200 : EUW1_6950733102
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 4300 : EUW1_6949743475
# Match wasnt ranked
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# 4400 : EUW1_6953102658
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 4500 : EUW1_6950068124
# sleeping w/ fc41
# sleeping w/ cb4d
# match data written at checkpoint: 4000
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 4600 : EUW1_6943778793
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 4700 : EUW1_6952129147
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 4800 : EUW1_6938521878
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# 4900 : EUW1_6950634630
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# sleeping w/ 8807
# 5000 : EUW1_6953295101
# Match wasnt ranked
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 5100 : EUW1_6934382933
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 5200 : EUW1_6958293282
# match data written at checkpoint: 4500
# sleeping w/ 228d
# sleeping w/ 8807
# 5300 : EUW1_6948712452
# sleeping w/ fc41
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# 5400 : EUW1_6956489275
# sleeping w/ e926
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 5500 : EUW1_6957191346
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# Match wasnt ranked
# sleeping w/ fc41
# 5600 : EUW1_6953606182
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 5700 : EUW1_6940773092
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# match data written at checkpoint: 5000
# 5800 : EUW1_6958733861
# sleeping w/ 8807
# sleeping w/ fc41
# Match wasnt ranked
# 5900 : EUW1_6955431190
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 6000 : EUW1_6955536808
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# 6100 : EUW1_6952242886
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# 6200 : EUW1_6958354252
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 6300 : EUW1_6954099571
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# match data written at checkpoint: 5500
# sleeping w/ fc41
# 6400 : EUW1_6951698023
# sleeping w/ cb4d
# sleeping w/ e926
# 6500 : EUW1_6946578919
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# 6600 : EUW1_6948696580
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# 6700 : EUW1_6948368020
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 6800 : EUW1_6948792875
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 6900 : EUW1_6949817602
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# match data written at checkpoint: 6000
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 7000 : EUW1_6946240811
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# 7100 : EUW1_6950550500
# Match wasnt ranked
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 7200 : EUW1_6948680664
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 7300 : EUW1_6956064872
# sleeping w/ e926
# sleeping w/ 228d
# 7400 : EUW1_6941412785
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 7500 : EUW1_6957104294
# Match wasnt ranked
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# match data written at checkpoint: 6500
# 7600 : EUW1_6956630662
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# Match wasnt ranked
# 7700 : EUW1_6956694212
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ fc41
# sleeping w/ cb4d
# 7800 : EUW1_6929671417
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# Match wasnt ranked
# sleeping w/ 228d
# 7900 : EUW1_6815936403
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 8000 : EUW1_6949923657
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# 8100 : EUW1_6955570053
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# match data written at checkpoint: 7000
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# 8200 : EUW1_6956614698
# Match wasnt ranked
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 8300 : EUW1_6955506001
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# 8400 : EUW1_6950798094
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# 8500 : EUW1_6952905377
# sleeping w/ fc41
# sleeping w/ cb4d
# 8600 : EUW1_6951782644
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 8700 : EUW1_6941382906
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# match data written at checkpoint: 7500
# Match wasnt ranked
# Match wasnt ranked
# 8800 : EUW1_6956481024
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# 8900 : EUW1_6941815728
# Match wasnt ranked
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# 9000 : EUW1_6944948730
# sleeping w/ 8807
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# 9100 : EUW1_6955462809
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# 9200 : EUW1_6945304229
# sleeping w/ 228d
# Match wasnt ranked
# sleeping w/ 8807
# 9300 : EUW1_6812921731
# match data written at checkpoint: 8000
# sleeping w/ fc41
# sleeping w/ cb4d
# 9400 : EUW1_6956454527
# Match wasnt ranked
# sleeping w/ e926
# sleeping w/ 228d
# 9500 : EUW1_6945540447
# sleeping w/ 8807
# sleeping w/ fc41
# 9600 : EUW1_6955200702
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# 9700 : EUW1_6940373297
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# 9800 : EUW1_6953573713
# Match wasnt ranked
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ fc41
# Match wasnt ranked
# match data written at checkpoint: 8500
# 9900 : EUW1_6950579036
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# 10000 : EUW1_6948493831
# sleeping w/ 228d
# Match wasnt ranked
# sleeping w/ 8807
# Match wasnt ranked
# 10100 : EUW1_6906202676
# sleeping w/ fc41
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# 10200 : EUW1_6930015649
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 10300 : EUW1_6956489048
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ fc41
# 10400 : EUW1_6957705574
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# match data written at checkpoint: 9000
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# 10500 : EUW1_6707057314
# sleeping w/ 228d
# sleeping w/ 8807
# 10600 : EUW1_6941046879
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ fc41
# sleeping w/ cb4d
# 10700 : EUW1_6930384371
# Match wasnt ranked
# sleeping w/ e926
# Match wasnt ranked
# 10800 : EUW1_6941573452
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 10900 : EUW1_6944738726
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 11000 : EUW1_6957568452
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# match data written at checkpoint: 9500
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 11100 : EUW1_6950969166
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 11200 : EUW1_6944643634
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# response is bad: 200
# response is bad: 502
# response is bad: 502
# response is bad: 200
# response is bad: 502
# sleeping w/ e926
# Match wasnt ranked
# 11300 : EUW1_6954093237
# response is bad: 502
# sleeping w/ 228d
# sleeping w/ 8807
# 11400 : EUW1_6944873444
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# Match wasnt ranked
# 11500 : EUW1_6949225038
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# match data written at checkpoint: 10000
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# 11600 : EUW1_6956566472
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# 11700 : EUW1_6953339619
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# 11800 : EUW1_6946564956
# sleeping w/ e926
# sleeping w/ 228d
# 11900 : EUW1_6947374872
# sleeping w/ 8807
# sleeping w/ fc41
# 12000 : EUW1_6881470153
# sleeping w/ cb4d
# Match wasnt ranked
# sleeping w/ e926
# 12100 : EUW1_6956326685
# match data written at checkpoint: 10500
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# sleeping w/ 8807
# 12200 : EUW1_6949558820
# sleeping w/ fc41
# Match wasnt ranked
# sleeping w/ cb4d
# 12300 : EUW1_6956965006
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# 12400 : EUW1_6957786227
# Match wasnt ranked
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 12500 : EUW1_6951197127
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 12600 : EUW1_6935504130
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 12700 : EUW1_6952160810
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# match data written at checkpoint: 11000
# sleeping w/ fc41
# 12800 : EUW1_6945403225
# Match wasnt ranked
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# 12900 : EUW1_6954351352
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# 13000 : EUW1_6947457484
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 13100 : EUW1_6940927293
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# Match wasnt ranked
# response is bad: 200
# 13200 : EUW1_6958129680
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 13300 : EUW1_6943153495
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ fc41
# match data written at checkpoint: 11500
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 13400 : EUW1_6955612848
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 13500 : EUW1_6948029299
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 13600 : EUW1_6954309859
# sleeping w/ fc41
# sleeping w/ cb4d
# 13700 : EUW1_6957447358
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 13800 : EUW1_6950094687
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# sleeping w/ fc41
# 13900 : EUW1_6921322047
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# match data written at checkpoint: 12000
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 14000 : EUW1_6956705341
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# 14100 : EUW1_6922669200
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# 14200 : EUW1_6951923105
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# sleeping w/ 228d
# 14300 : EUW1_6946857406
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 14400 : EUW1_6925753640
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# 14500 : EUW1_6949136263
# sleeping w/ e926
# match data written at checkpoint: 12500
# sleeping w/ 228d
# 14600 : EUW1_6934244185
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ fc41
# 14700 : EUW1_6874297930
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# 14800 : EUW1_6940190306
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# 14900 : EUW1_6946809316
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 15000 : EUW1_6953411516
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# 15100 : EUW1_6949431783
# match data written at checkpoint: 13000
# Match wasnt ranked
# sleeping w/ 8807
# Match wasnt ranked
# sleeping w/ fc41
# 15200 : EUW1_6949684073
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# 15300 : EUW1_6950690880
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 15400 : EUW1_6945464303
# Match wasnt ranked
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 15500 : EUW1_6951702951
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# sleeping w/ e926
# 15600 : EUW1_6942714756
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# match data written at checkpoint: 13500
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 15700 : EUW1_6946838114
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# Match wasnt ranked
# 15800 : EUW1_6956085172
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# ...
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 31200 : EUW1_6946323406
# sleeping w/ e926
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 31300 : EUW1_6951082080
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# 31400 : EUW1_6938445904
# Match wasnt ranked
# sleeping w/ cb4d
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 31500 : EUW1_6956709688
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 31600 : EUW1_6932525386
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 31700 : EUW1_6944512338
# sleeping w/ cb4d
# match data written at checkpoint: 26000
# sleeping w/ e926
# Match wasnt ranked
# 31800 : EUW1_6948960325
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 31900 : EUW1_6942342594
# sleeping w/ fc41
# sleeping w/ cb4d
# 32000 : EUW1_6948121216
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# 32100 : EUW1_6944568566
# sleeping w/ 8807
# Match wasnt ranked
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 32200 : EUW1_6951253627
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# sleeping w/ e926
# 32300 : EUW1_6930177648
# match data written at checkpoint: 26500
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 32400 : EUW1_6952188592
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ fc41
# 32500 : EUW1_6939704640
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 32600 : EUW1_6897370381
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 32700 : EUW1_6948784627
# Match wasnt ranked
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 32800 : EUW1_6953646063
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 32900 : EUW1_6927803150
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 33000 : EUW1_6947749613
# sleeping w/ 8807
# match data written at checkpoint: 27000
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 33100 : EUW1_6944468200
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 33200 : EUW1_6940064045
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# 33300 : EUW1_6952617948
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# 33400 : EUW1_6919743879
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# 33500 : EUW1_6944586582
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 33600 : EUW1_6946888465
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# Match wasnt ranked
# 33700 : EUW1_6949096916
# match data written at checkpoint: 27500
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# sleeping w/ 228d
# 33800 : EUW1_6940497045
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 33900 : EUW1_6953719614
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ fc41
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 34000 : EUW1_6916042141
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ e926
# sleeping w/ 228d
# 34100 : EUW1_6952095125
# Match wasnt ranked
# sleeping w/ 8807
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ fc41
# 34200 : EUW1_6951043368
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ cb4d
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 34300 : EUW1_6945094700
# sleeping w/ e926
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# sleeping w/ 228d
# Match wasnt ranked
# Match wasnt ranked
# match data written at checkpoint: 28000
# Match wasnt ranked
# Match wasnt ranked
# Match wasnt ranked
# 34400 : EUW1_6958575531
# sleeping w/ 8807
# sleeping w/ fc41

# %% [markdown]
# ## Getting the match data
# the following cell takes each of the match_ids and gets the match state at 15 minutes. Every 500 processed matches it saves the dataset into a match_data.csv file.

# %%
with open('match_data.csv', 'w', newline='') as file:
  writer = csv.writer(file)
  writer.writerows(data[1:])

# %%
player_ids = player_ids
match_ids = match_ids
